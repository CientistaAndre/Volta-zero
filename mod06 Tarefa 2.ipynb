# %% [markdown]
# # Módulo 06 Tarefa 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline
sns.set_style("whitegrid")

sinasc = pd.read_csv('b1abb33c4f.csv')

# %% [markdown]
# ####  1) Na base do SINASC do DataSUS, faça um boxplot da idade da mãe.

# %%
idades_box = pd.DataFrame(sinasc['IDADEMAE'])
idades_box.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ####  2) Faça um boxplot do peso do bebê

# %%
peso_box = pd.DataFrame(sinasc['PESO'])
peso_box.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ####  3) Faça um histograma da idade da mãe

# %%
idade_hist = pd.DataFrame(sinasc['IDADEMAE'])
idade_hist.hist()
# Out:
# array([[<AxesSubplot:title={'center':'IDADEMAE'}>]], dtype=object)

# %% [markdown]
# #### 4) Faça um histograma do peso do bebê

# %%
peso_hist = pd.DataFrame(sinasc['PESO'])
peso_hist.hist()
# Out:
# array([[<AxesSubplot:title={'center':'PESO'}>]], dtype=object)
